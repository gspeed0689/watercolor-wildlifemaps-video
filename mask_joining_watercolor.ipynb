# %% [markdown]
# We'll need the Python Image Library descendant PILLOW. Pathlib and OS libraries are also very helpful.

# %%
from PIL import Image, ImageFilter
import pathlib
import os

# %% [markdown]
# Let's gather all our categories (data types) and places (maps).

# %%
ps_watercolor_dir = pathlib.Path("./photoshopped/")
masks = list(ps_watercolor_dir.glob("*.png"))

categories = []
places = []

for mask in masks:
    s = mask.stem.split("_")
    category, place = s[0], s[1]
    if category not in categories:
        categories.append(category)
    if place not in places:
        places.append(place)

print(categories)
print(places)
# Out:
# ['beach', 'buildings', 'farms', 'forest', 'grass', 'heath', 'highways', 'industrial', 'land', 'local-roads', 'major-roads', 'metro', 'parking', 'parks', 'pedestrian', 'train', 'trams', 'water']
# ['Bossche Broek', 'Danska Falls', 'Den Bosch', 'Engelen', 'Halmstad', 'Maas Gement', 'Pozzuoli', 'Procida', 'Zaltbommel', 'Bleyenbeek', 'Camden', 'Komosse Naturreservat', 'Mullsjön', 'Nationaal park Söderåsen', 'Pompeii', 'Rotterdam', 'Tenhultasjön', 'Utrecht Science Park', 'Vomero', 'Wandelpark Tegelen', 'Copenhagen', 'Moerputten', 'Nationaal Park De Meinweg', 'Nationaal Park Utrechtse Heulvelrug', 'Nationaal Park Veluwezoom', 'Lyngemadssjön', 'Mariesholmsskogen']

# %% [markdown]
# Gather all the filenames for the watercolor textures.

# %%
watercategories_dir = pathlib.Path(r"U:\Photos_2023\Wildlife2023\Watercolors\categorized")
watercolors = list(watercategories_dir.glob("*.png"))
watercategories = [x.stem for x in watercolors]
print(watercolors)
print(watercategories)
# Out:
# [WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/beach.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/buildings.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/farms.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/forest.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/grass.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/heath.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/industrial.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/land.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/parking.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/parks.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/pedestrian.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/roads.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/trains.png'), WindowsPath('U:/Photos_2023/Wildlife2023/Watercolors/categorized/water.png')]
# ['beach', 'buildings', 'farms', 'forest', 'grass', 'heath', 'industrial', 'land', 'parking', 'parks', 'pedestrian', 'roads', 'trains', 'water']

# %% [markdown]
# Some data types will use the same watercolor texture, so I need to map the data types to their shared texture.

# %%
watercolor_mapping = {}
needs_intervention = []

for category in categories:
    if category in watercategories:
        watercolor_mapping[category] = category
    else:
        needs_intervention.append(category)

watercolor_mapping["train"] = "trains"
watercolor_mapping["metro"] = "trains"
watercolor_mapping["trams"] = "trains"
watercolor_mapping["highways"] = "roads"
watercolor_mapping["major-roads"] = "roads"
watercolor_mapping["local-roads"] = "roads"

print(watercolor_mapping)
print([x for x in needs_intervention if x not in watercolor_mapping.keys()])
# Out:
# {'beach': 'beach', 'buildings': 'buildings', 'farms': 'farms', 'forest': 'forest', 'grass': 'grass', 'heath': 'heath', 'industrial': 'industrial', 'land': 'land', 'parking': 'parking', 'parks': 'parks', 'pedestrian': 'pedestrian', 'water': 'water', 'train': 'trains', 'metro': 'trains', 'trams': 'trains', 'highways': 'roads', 'major-roads': 'roads', 'local-roads': 'roads'}
# []

# %% [markdown]
# Apply the masks to the textures, randomly rotate the textures so they don't look exactly the same in every map.

# %%
from random import choice
import PIL
from IPython.display import display
output_built = pathlib.Path(r"U:\Photos_2023\Wildlife2023\built_images")

c = 1
for mask in masks[:]:
    s = mask.stem.split("_")
    category, place = s[0], s[1]
    print(f"{category} -- {place} -- {c} of {len(masks)}")
    outpath = output_built/f"{category}_{place}.png"
    if os.path.exists(outpath) == False:
        print("\tProcessing")
        mask_img = Image.open(mask)
        watercolor_texture = watercategories_dir / f"{watercolor_mapping[category]}.png"
        texture_img = Image.open(watercolor_texture)
        texture_img = texture_img.convert(mode="RGB")
        rotation = choice([0, 90, 180, 270])
        texture_img = texture_img.rotate(rotation, PIL.Image.NEAREST, expand = 1)
        texture_img.putalpha(mask_img)
        texture_img.save(outpath)
    else:
        print("\tEXISTS")
    c+=1
# Out:
# beach -- Bossche Broek -- 1 of 286
# 	EXISTS
# beach -- Danska Falls -- 2 of 286
# 	EXISTS
# beach -- Den Bosch -- 3 of 286
# 	EXISTS
# beach -- Engelen -- 4 of 286
# 	EXISTS
# beach -- Halmstad -- 5 of 286
# 	EXISTS
# beach -- Maas Gement -- 6 of 286
# 	EXISTS
# beach -- Pozzuoli -- 7 of 286
# 	EXISTS
# beach -- Procida -- 8 of 286
# 	EXISTS
# beach -- Zaltbommel -- 9 of 286
# 	EXISTS
# buildings -- Bleyenbeek -- 10 of 286
# 	EXISTS
# buildings -- Bossche Broek -- 11 of 286
# 	EXISTS
# buildings -- Camden -- 12 of 286
# 	EXISTS
# buildings -- Danska Falls -- 13 of 286
# 	EXISTS
# buildings -- Den Bosch -- 14 of 286
# 	EXISTS
# buildings -- Engelen -- 15 of 286
# 	EXISTS
# buildings -- Halmstad -- 16 of 286
# 	EXISTS
# buildings -- Komosse Naturreservat -- 17 of 286
# 	EXISTS
# buildings -- Maas Gement -- 18 of 286
# 	EXISTS
# buildings -- Mullsjön -- 19 of 286
# 	EXISTS
# buildings -- Nationaal park Söderåsen -- 20 of 286
# 	EXISTS
# buildings -- Pompeii -- 21 of 286
# 	EXISTS
# buildings -- Pozzuoli -- 22 of 286
# 	EXISTS
# buildings -- Procida -- 23 of 286
# 	EXISTS
# buildings -- Rotterdam -- 24 of 286
# 	EXISTS
# buildings -- Tenhultasjön -- 25 of 286
# 	EXISTS
# buildings -- Utrecht Science Park -- 26 of 286
# 	EXISTS
# buildings -- Vomero -- 27 of 286
# 	EXISTS
# buildings -- Wandelpark Tegelen -- 28 of 286
# 	EXISTS
# buildings -- Zaltbommel -- 29 of 286
# 	EXISTS
# farms -- Bleyenbeek -- 30 of 286
# 	EXISTS
# farms -- Bossche Broek -- 31 of 286
# 	EXISTS
# farms -- Copenhagen -- 32 of 286
# 	EXISTS
# farms -- Den Bosch -- 33 of 286
# 	EXISTS
# farms -- Engelen -- 34 of 286
# 	EXISTS
# farms -- Halmstad -- 35 of 286
# 	EXISTS
# farms -- Maas Gement -- 36 of 286
# 	EXISTS
# farms -- Moerputten -- 37 of 286
# 	EXISTS
# farms -- Mullsjön -- 38 of 286
# 	EXISTS
# farms -- Nationaal Park De Meinweg -- 39 of 286
# 	EXISTS
# farms -- Nationaal park Söderåsen -- 40 of 286
# 	EXISTS
# farms -- Nationaal Park Utrechtse Heulvelrug -- 41 of 286
# 	EXISTS
# farms -- Nationaal Park Veluwezoom -- 42 of 286
# 	EXISTS
# farms -- Pompeii -- 43 of 286
# 	EXISTS
# farms -- Pozzuoli -- 44 of 286
# 	EXISTS
# farms -- Procida -- 45 of 286
# 	EXISTS
# farms -- Rotterdam -- 46 of 286
# 	EXISTS
# farms -- Tenhultasjön -- 47 of 286
# 	EXISTS
# farms -- Utrecht Science Park -- 48 of 286
# 	EXISTS
# farms -- Vomero -- 49 of 286
# 	EXISTS
# farms -- Wandelpark Tegelen -- 50 of 286
# 	EXISTS
# farms -- Zaltbommel -- 51 of 286
# 	EXISTS
# forest -- Bleyenbeek -- 52 of 286
# 	EXISTS
# forest -- Bossche Broek -- 53 of 286
# 	EXISTS
# forest -- Camden -- 54 of 286
# 	EXISTS
# forest -- Copenhagen -- 55 of 286
# 	EXISTS
# forest -- Danska Falls -- 56 of 286
# 	EXISTS
# forest -- Den Bosch -- 57 of 286
# 	EXISTS
# forest -- Engelen -- 58 of 286
# 	EXISTS
# forest -- Halmstad -- 59 of 286
# 	EXISTS
# forest -- Komosse Naturreservat -- 60 of 286
# 	EXISTS
# forest -- Lyngemadssjön -- 61 of 286
# 	EXISTS
# forest -- Maas Gement -- 62 of 286
# 	EXISTS
# forest -- Mariesholmsskogen -- 63 of 286
# 	EXISTS
# forest -- Moerputten -- 64 of 286
# 	EXISTS
# forest -- Mullsjön -- 65 of 286
# 	EXISTS
# forest -- Nationaal Park De Meinweg -- 66 of 286
# 	EXISTS
# forest -- Nationaal park Söderåsen -- 67 of 286
# 	EXISTS
# forest -- Nationaal Park Utrechtse Heulvelrug -- 68 of 286
# 	EXISTS
# forest -- Nationaal Park Veluwezoom -- 69 of 286
# 	EXISTS
# forest -- Pompeii -- 70 of 286
# 	EXISTS
# forest -- Pozzuoli -- 71 of 286
# 	EXISTS
# forest -- Rotterdam -- 72 of 286
# 	EXISTS
# forest -- Tenhultasjön -- 73 of 286
# 	EXISTS
# forest -- Utrecht Science Park -- 74 of 286
# 	EXISTS
# forest -- Vomero -- 75 of 286
# 	EXISTS
# forest -- Wandelpark Tegelen -- 76 of 286
# 	EXISTS
# forest -- Zaltbommel -- 77 of 286
# 	EXISTS
# grass -- Bleyenbeek -- 78 of 286
# 	EXISTS
# grass -- Bossche Broek -- 79 of 286
# 	EXISTS
# grass -- Camden -- 80 of 286
# 	EXISTS
# grass -- Copenhagen -- 81 of 286
# 	EXISTS
# grass -- Danska Falls -- 82 of 286
# 	EXISTS
# grass -- Den Bosch -- 83 of 286
# 	EXISTS
# grass -- Engelen -- 84 of 286
# 	EXISTS
# grass -- Halmstad -- 85 of 286
# 	EXISTS
# grass -- Maas Gement -- 86 of 286
# 	EXISTS
# grass -- Mariesholmsskogen -- 87 of 286
# 	EXISTS
# grass -- Moerputten -- 88 of 286
# 	EXISTS
# grass -- Mullsjön -- 89 of 286
# 	EXISTS
# grass -- Nationaal Park De Meinweg -- 90 of 286
# 	EXISTS
# grass -- Nationaal park Söderåsen -- 91 of 286
# 	EXISTS
# grass -- Nationaal Park Utrechtse Heulvelrug -- 92 of 286
# 	EXISTS
# grass -- Nationaal Park Veluwezoom -- 93 of 286
# 	EXISTS
# grass -- Pompeii -- 94 of 286
# 	EXISTS
# grass -- Pozzuoli -- 95 of 286
# 	EXISTS
# grass -- Procida -- 96 of 286
# 	EXISTS
# grass -- Rotterdam -- 97 of 286
# 	EXISTS
# grass -- Tenhultasjön -- 98 of 286
# 	EXISTS
# grass -- Utrecht Science Park -- 99 of 286
# 	EXISTS
# grass -- Vomero -- 100 of 286
# 	EXISTS
# grass -- Wandelpark Tegelen -- 101 of 286
# 	EXISTS
# grass -- Zaltbommel -- 102 of 286
# 	EXISTS
# heath -- Bleyenbeek -- 103 of 286
# 	EXISTS
# heath -- Engelen -- 104 of 286
# 	EXISTS
# heath -- Halmstad -- 105 of 286
# 	EXISTS
# heath -- Nationaal Park De Meinweg -- 106 of 286
# 	EXISTS
# heath -- Nationaal Park Utrechtse Heulvelrug -- 107 of 286
# 	EXISTS
# heath -- Nationaal Park Veluwezoom -- 108 of 286
# 	EXISTS
# heath -- Pompeii -- 109 of 286
# 	EXISTS
# heath -- Procida -- 110 of 286
# 	EXISTS
# highways -- Bossche Broek -- 111 of 286
# 	EXISTS
# highways -- Camden -- 112 of 286
# 	EXISTS
# highways -- Engelen -- 113 of 286
# 	EXISTS
# highways -- Halmstad -- 114 of 286
# 	EXISTS
# highways -- Maas Gement -- 115 of 286
# 	EXISTS
# highways -- Moerputten -- 116 of 286
# 	EXISTS
# highways -- Nationaal Park De Meinweg -- 117 of 286
# 	EXISTS
# highways -- Nationaal Park Utrechtse Heulvelrug -- 118 of 286
# 	EXISTS
# highways -- Nationaal Park Veluwezoom -- 119 of 286
# 	EXISTS
# highways -- Pompeii -- 120 of 286
# 	EXISTS
# highways -- Utrecht Science Park -- 121 of 286
# 	EXISTS
# highways -- Wandelpark Tegelen -- 122 of 286
# 	EXISTS
# highways -- Zaltbommel -- 123 of 286
# 	EXISTS
# industrial -- Bleyenbeek -- 124 of 286
# 	EXISTS
# industrial -- Bossche Broek -- 125 of 286
# 	EXISTS
# industrial -- Copenhagen -- 126 of 286
# 	EXISTS
# industrial -- Den Bosch -- 127 of 286
# 	EXISTS
# industrial -- Engelen -- 128 of 286
# 	EXISTS
# industrial -- Halmstad -- 129 of 286
# 	EXISTS
# industrial -- Maas Gement -- 130 of 286
# 	EXISTS
# industrial -- Moerputten -- 131 of 286
# 	EXISTS
# industrial -- Nationaal Park De Meinweg -- 132 of 286
# 	EXISTS
# industrial -- Nationaal Park Utrechtse Heulvelrug -- 133 of 286
# 	EXISTS
# industrial -- Nationaal Park Veluwezoom -- 134 of 286
# 	EXISTS
# industrial -- Pompeii -- 135 of 286
# 	EXISTS
# industrial -- Rotterdam -- 136 of 286
# 	EXISTS
# industrial -- Tenhultasjön -- 137 of 286
# 	EXISTS
# industrial -- Utrecht Science Park -- 138 of 286
# 	EXISTS
# industrial -- Wandelpark Tegelen -- 139 of 286
# 	EXISTS
# industrial -- Zaltbommel -- 140 of 286
# 	EXISTS
# land -- Copenhagen -- 141 of 286
# 	EXISTS
# land -- Halmstad -- 142 of 286
# 	EXISTS
# land -- Pozzuoli -- 143 of 286
# 	EXISTS
# land -- Procida -- 144 of 286
# 	EXISTS
# land -- Vomero -- 145 of 286
# 	EXISTS
# local-roads -- Bossche Broek -- 146 of 286
# 	EXISTS
# local-roads -- Camden -- 147 of 286
# 	EXISTS
# local-roads -- Danska Falls -- 148 of 286
# 	EXISTS
# local-roads -- Maas Gement -- 149 of 286
# 	EXISTS
# local-roads -- Nationaal park Söderåsen -- 150 of 286
# 	EXISTS
# local-roads -- Pompeii -- 151 of 286
# 	EXISTS
# local-roads -- Pozzuoli -- 152 of 286
# 	EXISTS
# local-roads -- Procida -- 153 of 286
# 	EXISTS
# local-roads -- Rotterdam -- 154 of 286
# 	EXISTS
# local-roads -- Utrecht Science Park -- 155 of 286
# 	EXISTS
# local-roads -- Vomero -- 156 of 286
# 	EXISTS
# local-roads -- Wandelpark Tegelen -- 157 of 286
# 	EXISTS
# local-roads -- Zaltbommel -- 158 of 286
# 	EXISTS
# major-roads -- Bleyenbeek -- 159 of 286
# 	EXISTS
# major-roads -- Bossche Broek -- 160 of 286
# 	EXISTS
# major-roads -- Camden -- 161 of 286
# 	EXISTS
# major-roads -- Copenhagen -- 162 of 286
# 	EXISTS
# major-roads -- Danska Falls -- 163 of 286
# 	EXISTS
# major-roads -- Den Bosch -- 164 of 286
# 	EXISTS
# major-roads -- Engelen -- 165 of 286
# 	EXISTS
# major-roads -- Halmstad -- 166 of 286
# 	EXISTS
# major-roads -- Komosse Naturreservat -- 167 of 286
# 	EXISTS
# major-roads -- Maas Gement -- 168 of 286
# 	EXISTS
# major-roads -- Mariesholmsskogen -- 169 of 286
# 	EXISTS
# major-roads -- Moerputten -- 170 of 286
# 	EXISTS
# major-roads -- Mullsjön -- 171 of 286
# 	EXISTS
# major-roads -- Nationaal Park De Meinweg -- 172 of 286
# 	EXISTS
# major-roads -- Nationaal park Söderåsen -- 173 of 286
# 	EXISTS
# major-roads -- Nationaal Park Utrechtse Heulvelrug -- 174 of 286
# 	EXISTS
# major-roads -- Nationaal Park Veluwezoom -- 175 of 286
# 	EXISTS
# major-roads -- Pompeii -- 176 of 286
# 	EXISTS
# major-roads -- Pozzuoli -- 177 of 286
# 	EXISTS
# major-roads -- Procida -- 178 of 286
# 	EXISTS
# major-roads -- Rotterdam -- 179 of 286
# 	EXISTS
# major-roads -- Tenhultasjön -- 180 of 286
# 	EXISTS
# major-roads -- Utrecht Science Park -- 181 of 286
# 	EXISTS
# major-roads -- Vomero -- 182 of 286
# 	EXISTS
# major-roads -- Wandelpark Tegelen -- 183 of 286
# 	EXISTS
# major-roads -- Zaltbommel -- 184 of 286
# 	EXISTS
# metro -- Camden -- 185 of 286
# 	EXISTS
# metro -- Rotterdam -- 186 of 286
# 	EXISTS
# metro -- Utrecht Science Park -- 187 of 286
# 	EXISTS
# metro -- Vomero -- 188 of 286
# 	EXISTS
# parking -- Bleyenbeek -- 189 of 286
# 	EXISTS
# parking -- Bossche Broek -- 190 of 286
# 	EXISTS
# parking -- Camden -- 191 of 286
# 	EXISTS
# parking -- Danska Falls -- 192 of 286
# 	EXISTS
# parking -- Den Bosch -- 193 of 286
# 	EXISTS
# parking -- Engelen -- 194 of 286
# 	EXISTS
# parking -- Halmstad -- 195 of 286
# 	EXISTS
# parking -- Komosse Naturreservat -- 196 of 286
# 	EXISTS
# parking -- Maas Gement -- 197 of 286
# 	EXISTS
# parking -- Nationaal park Söderåsen -- 198 of 286
# 	EXISTS
# parking -- Pompeii -- 199 of 286
# 	EXISTS
# parking -- Pozzuoli -- 200 of 286
# 	EXISTS
# parking -- Procida -- 201 of 286
# 	EXISTS
# parking -- Rotterdam -- 202 of 286
# 	EXISTS
# parking -- Tenhultasjön -- 203 of 286
# 	EXISTS
# parking -- Utrecht Science Park -- 204 of 286
# 	EXISTS
# parking -- Vomero -- 205 of 286
# 	EXISTS
# parking -- Wandelpark Tegelen -- 206 of 286
# 	EXISTS
# parking -- Zaltbommel -- 207 of 286
# 	EXISTS
# parks -- Bossche Broek -- 208 of 286
# 	EXISTS
# parks -- Camden -- 209 of 286
# 	EXISTS
# parks -- Copenhagen -- 210 of 286
# 	EXISTS
# parks -- Den Bosch -- 211 of 286
# 	EXISTS
# parks -- Engelen -- 212 of 286
# 	EXISTS
# parks -- Halmstad -- 213 of 286
# 	EXISTS
# parks -- Maas Gement -- 214 of 286
# 	EXISTS
# parks -- Moerputten -- 215 of 286
# 	EXISTS
# parks -- Nationaal Park Utrechtse Heulvelrug -- 216 of 286
# 	EXISTS
# parks -- Nationaal Park Veluwezoom -- 217 of 286
# 	EXISTS
# parks -- Pompeii -- 218 of 286
# 	EXISTS
# parks -- Pozzuoli -- 219 of 286
# 	EXISTS
# parks -- Procida -- 220 of 286
# 	EXISTS
# parks -- Rotterdam -- 221 of 286
# 	EXISTS
# parks -- Tenhultasjön -- 222 of 286
# 	EXISTS
# parks -- Utrecht Science Park -- 223 of 286
# 	EXISTS
# parks -- Vomero -- 224 of 286
# 	EXISTS
# parks -- Wandelpark Tegelen -- 225 of 286
# 	EXISTS
# parks -- Zaltbommel -- 226 of 286
# 	EXISTS
# pedestrian -- Bleyenbeek -- 227 of 286
# 	EXISTS
# pedestrian -- Camden -- 228 of 286
# 	EXISTS
# pedestrian -- Danska Falls -- 229 of 286
# 	EXISTS
# pedestrian -- Lyngemadssjön -- 230 of 286
# 	EXISTS
# pedestrian -- Maas Gement -- 231 of 286
# 	EXISTS
# pedestrian -- Mariesholmsskogen -- 232 of 286
# 	EXISTS
# pedestrian -- Nationaal park Söderåsen -- 233 of 286
# 	EXISTS
# pedestrian -- Pompeii -- 234 of 286
# 	EXISTS
# pedestrian -- Pozzuoli -- 235 of 286
# 	EXISTS
# pedestrian -- Procida -- 236 of 286
# 	EXISTS
# pedestrian -- Rotterdam -- 237 of 286
# 	EXISTS
# pedestrian -- Utrecht Science Park -- 238 of 286
# 	EXISTS
# pedestrian -- Vomero -- 239 of 286
# 	EXISTS
# pedestrian -- Wandelpark Tegelen -- 240 of 286
# 	EXISTS
# pedestrian -- Zaltbommel -- 241 of 286
# 	EXISTS
# train -- Bossche Broek -- 242 of 286
# 	Processing
# train -- Camden -- 243 of 286
# 	Processing
# train -- Copenhagen -- 244 of 286
# 	Processing
# train -- Den Bosch -- 245 of 286
# 	Processing
# train -- Engelen -- 246 of 286
# 	Processing
# train -- Halmstad -- 247 of 286
# 	Processing
# train -- Maas Gement -- 248 of 286
# 	Processing
# train -- Moerputten -- 249 of 286
# 	Processing
# train -- Nationaal Park De Meinweg -- 250 of 286
# 	Processing
# train -- Nationaal Park Utrechtse Heulvelrug -- 251 of 286
# 	Processing
# train -- Nationaal Park Veluwezoom -- 252 of 286
# 	Processing
# train -- Pompeii -- 253 of 286
# 	Processing
# train -- Pozzuoli -- 254 of 286
# 	Processing
# train -- Rotterdam -- 255 of 286
# 	Processing
# train -- Tenhultasjön -- 256 of 286
# 	Processing
# train -- Vomero -- 257 of 286
# 	Processing
# train -- Wandelpark Tegelen -- 258 of 286
# 	Processing
# train -- Zaltbommel -- 259 of 286
# 	Processing
# trams -- Rotterdam -- 260 of 286
# 	Processing
# water -- Bleyenbeek -- 261 of 286
# 	Processing
# water -- Bossche Broek -- 262 of 286
# 	Processing
# water -- Camden -- 263 of 286
# 	Processing
# water -- Copenhagen -- 264 of 286
# 	Processing
# water -- Danska Falls -- 265 of 286
# 	Processing
# water -- Den Bosch -- 266 of 286
# 	Processing
# water -- Engelen -- 267 of 286
# 	Processing
# water -- Halmstad -- 268 of 286
# 	Processing
# water -- Komosse Naturreservat -- 269 of 286
# 	Processing
# water -- Lyngemadssjön -- 270 of 286
# 	Processing
# water -- Maas Gement -- 271 of 286
# 	Processing
# water -- Mariesholmsskogen -- 272 of 286
# 	Processing
# water -- Moerputten -- 273 of 286
# 	Processing
# water -- Mullsjön -- 274 of 286
# 	Processing
# water -- Nationaal Park De Meinweg -- 275 of 286
# 	Processing
# water -- Nationaal park Söderåsen -- 276 of 286
# 	Processing
# water -- Nationaal Park Utrechtse Heulvelrug -- 277 of 286
# 	Processing
# water -- Nationaal Park Veluwezoom -- 278 of 286
# 	Processing
# water -- Pozzuoli -- 279 of 286
# 	Processing
# water -- Procida -- 280 of 286
# 	Processing
# water -- Rotterdam -- 281 of 286
# 	Processing
# water -- Tenhultasjön -- 282 of 286
# 	Processing
# water -- Utrecht Science Park -- 283 of 286
# 	Processing
# water -- Vomero -- 284 of 286
# 	Processing
# water -- Wandelpark Tegelen -- 285 of 286
# 	Processing
# water -- Zaltbommel -- 286 of 286
# 	Processing

# %% [markdown]
# Sometimes the land texture, being a complete white mask produced errors, so just randomly rotate and rename land texture and export to the GIS folder.

# %%
for place in places:
    outpath = output_built / f"land_{place}.png"
    if os.path.exists(outpath) == False:
        texture_img = Image.open(r"U:\Photos_2023\Wildlife2023\Watercolors\categorized\land.png")
        texture_img = texture_img.convert(mode="RGB")
        rotation = choice([0, 90, 180, 270])
        texture_img = texture_img.rotate(rotation, PIL.Image.NEAREST, expand = 1)
        texture_img.save(outpath)
